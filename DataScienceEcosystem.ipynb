# %% [markdown]
# Ex-2 Markdown cell with title "Data Science Tools and Ecosystem with screenshot with heading:

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:2-title.png)

# %% [markdown]
#  Ex-3 Markdown cell with title and screenshot(without heading):

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-Intro.png](attachment:3-Intro.png)

# %% [markdown]
# **Objectives**
# - Creating a Jupyter Notebook.
# - Markdown cell with title of Notebook.
# - Markdown cell with a table of data science tools.
# - Cells to multiply and add numbers.
# - Cells to convert minutes into hours.

# %% [markdown]
# Ex-4 Markdown cell listing Data Science languages alongwith screenshot:

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. SQL
# 2. Python
# 3. R
# 4. Matlab

# %% [markdown]
# ![4-dslanguages.png](attachment:4-dslanguages.png)

# %% [markdown]
# Ex-5 List of Data Science liberaries:

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# ![5-dslibraries.png](attachment:5-dslibraries.png)

# %% [markdown]
# Ex-6 Data Science tools along with screenshot.

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | Rstudio            |
# | Spyder             |

# %% [markdown]
# ![6-dstools.png](attachment:6-dstools.png)

# %% [markdown]
# Ex -7 markdown cell introducing arithmetic expression examples with screenshot.

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:7-introarithmetic.png)

# %% [markdown]
# Ex-8 Code cell to multiply and add numbers with screenshot.

# %%
(3*4) + 5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:8-multiplyandaddintegers.png)

# %% [markdown]
# Ex-9 - Code cell to convert minutes to hours with Screenshot.

# %%
minutes = 200
hours = minutes /60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:9-hourstominutes.png)

# %% [markdown]
# Ex-10 Markdown cell listing Objectives given below the screenshot.

# %% [markdown]
# ![10-objectives.png](attachment:10-objectives.png)

# %% [markdown]
# Ex-11 Markdown cell indicating author's name with screenshot.

# %% [markdown]
# ## Author
#
# Lakshmi Holla
#
# Niveditha Pandith

# %% [markdown]
# ![11-authordetails.png](attachment:11-authordetails.png)
